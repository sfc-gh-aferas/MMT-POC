# %%
! pip install optuna lightgbm darts tsfresh mapie scikit-lego statsmodels scipy scikit-learn

# %%
! pip install tsfresh

# %%
from utils import create_session
from actual_demand_forecast_spcs import prepare_data, execute_training

session = create_session()

# %%
session.use_role("ML_DEV_ROLE")
session.use_database("DEMAND_FORECAST_POC")
session.use_schema("FORECASTING")
prepare_data(session)

# %%
from actual_demand_forecast_spcs import get_train_version

train_version = get_train_version()
run_id = f"forecast_{train_version}"

execute_training(session,run_id)

# %%
! pip list
